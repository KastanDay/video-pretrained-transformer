# %%
# Install mmcv
## CAUTION: The latest versions of mmcv 1.5.3, mmdet 2.25.0 are not well supported, due to bugs in mmdet.
# !pip install mmcv-full==1.4.3 -f https://download.openmmlab.com/mmcv/dist/cu101/torch1.7.0/index.html

# Install mmdet
# !pip install openmim
# !mim install mmdet==2.20.0
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu101/torch1.7.0/index.html
# Requirement already satisfied: mmcv-full==1.4.3 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (1.4.3)
# Requirement already satisfied: opencv-python>=3 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from mmcv-full==1.4.3) (4.6.0.66)
# Requirement already satisfied: packaging in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from mmcv-full==1.4.3) (21.3)
# Requirement already satisfied: pyyaml in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from mmcv-full==1.4.3) (6.0)
# Requirement already satisfied: Pillow in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from mmcv-full==1.4.3) (9.2.0)
# Requirement already satisfied: yapf in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from mmcv-full==1.4.3) (0.32.0)
# Requirement already satisfied: numpy in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from mmcv-full==1.4.3) (1.21.5)
# Requirement already satisfied: addict in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from mmcv-full==1.4.3) (2.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from packaging->mmcv-full==1.4.3) (3.0.9)
# Requirement already satisfied: openmim in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (0.3.2)
# Requirement already satisfied: Click in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from openmim) (8.1.3)
# Requirement already satisfied: pandas in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from openmim) (1.3.5)
# Requirement already satisfied: rich in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from openmim) (12.6.0)
# Requirement already satisfied: tabulate in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from openmim) (0.9.0)
# Requirement already satisfied: pip>=19.3 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from openmim) (22.2.2)
# Requirement already satisfied: requests in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from openmim) (2.28.1)
# Requirement already satisfied: colorama in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from openmim) (0.4.6)
# Requirement already satisfied: model-index in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from openmim) (0.1.11)
# Requirement already satisfied: importlib-metadata in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from Click->openmim) (5.0.0)
# Requirement already satisfied: markdown in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from model-index->openmim) (3.4.1)
# Requirement already satisfied: ordered-set in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from model-index->openmim) (4.1.0)
# Requirement already satisfied: pyyaml in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from model-index->openmim) (6.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from pandas->openmim) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from pandas->openmim) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from pandas->openmim) (2022.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from requests->openmim) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from requests->openmim) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from requests->openmim) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from requests->openmim) (3.4)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from rich->openmim) (2.13.0)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from rich->openmim) (4.3.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from rich->openmim) (0.9.1)
# Requirement already satisfied: six>=1.5 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->openmim) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from importlib-metadata->Click->openmim) (3.10.0)
# /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu101/torch1.7.0/index.html
# Collecting mmdet==2.20.0
#   Downloading mmdet-2.20.0-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 31.2 MB/s eta 0:00:0000:01
# Collecting mmdet==2.20.0
#   Downloading mmdet-2.20.0.tar.gz (682 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 682.7/682.7 kB 23.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Saved /tmp/tmpd55xxhx4/mmdet-2.20.0.tar.gz
# Successfully downloaded mmdet
# Get 'mim' extra requirements from `mminstall.txt` for mmdet 2.20.0: ['mmcv-full>=1.3.17'].
# Collecting pycocotools
#   Using cached pycocotools-2.0.5.tar.gz (24 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting terminaltables
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 43.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: six in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from mmdet==2.20.0) (1.16.0)
# Requirement already satisfied: numpy in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from mmdet==2.20.0) (1.21.5)
# Requirement already satisfied: mmcv-full>=1.3.17 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from mmdet==2.20.0) (1.4.3)
# Requirement already satisfied: yapf in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from mmcv-full>=1.3.17->mmdet==2.20.0) (0.32.0)
# Requirement already satisfied: Pillow in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from mmcv-full>=1.3.17->mmdet==2.20.0) (9.2.0)
# Requirement already satisfied: opencv-python>=3 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from mmcv-full>=1.3.17->mmdet==2.20.0) (4.6.0.66)
# Requirement already satisfied: pyyaml in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from mmcv-full>=1.3.17->mmdet==2.20.0) (6.0)
# Requirement already satisfied: addict in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from mmcv-full>=1.3.17->mmdet==2.20.0) (2.4.0)
# Requirement already satisfied: packaging in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from mmcv-full>=1.3.17->mmdet==2.20.0) (21.3)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.38.0-py3-none-any.whl (965 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from matplotlib->mmdet==2.20.0) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from matplotlib->mmdet==2.20.0) (3.0.9)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 51.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib->mmdet==2.20.0) (4.3.0)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (pyproject.toml) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0.5-cp37-cp37m-linux_x86_64.whl size=373420 sha256=35d514ad16180ffa7f9fb8acc818295a0f32b099f2d5d326de289a8e8af8f136
#   Stored in directory: /home/kastan/.cache/pip/wheels/85/c4/f0/7128093a134f590e4383fd60cb484960878721d98b9a515317
# Successfully built pycocotools
# Using cached `mminstall.txt` for mmdet==2.20.0: /home/kastan/.cache/mim/mminstall/mmdet==2.20.0.txt
# Get 'mim' extra requirements from `mminstall.txt` for mmdet 2.20.0: ['mmcv-full>=1.3.17'].
# Installing collected packages: terminaltables, kiwisolver, fonttools, cycler, matplotlib, pycocotools, mmdet
# Successfully installed cycler-0.11.0 fonttools-4.38.0 kiwisolver-1.4.4 matplotlib-3.5.3 mmdet-2.20.0 pycocotools-2.0.5 terminaltables-3.1.10

# %%
# Install coco panopticapi
# !pip install git+https://github.com/cocodataset/panopticapi.git

# For visualization
# !conda install -c conda-forge pycocotools -y
# !pip install detectron2==0.5 -f \
  https://dl.fbaipublicfiles.com/detectron2/wheels/cu101/torch1.7/index.html
# Out:
# Collecting git+https://github.com/cocodataset/panopticapi.git
#   Cloning https://github.com/cocodataset/panopticapi.git to /tmp/pip-req-build-_6ivqg6z
#   Running command git clone --filter=blob:none --quiet https://github.com/cocodataset/panopticapi.git /tmp/pip-req-build-_6ivqg6z
#   Resolved https://github.com/cocodataset/panopticapi.git to commit 7bb4655548f98f3fedc07bf37e9040a992b054b0
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from panopticapi==0.1) (1.21.5)
# Requirement already satisfied: Pillow in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from panopticapi==0.1) (9.2.0)
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/kastan/utils/miniconda3/envs/openpsg
#
#   added / updated specs:
#     - pycocotools
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cython-0.29.32             |   py37h6a678d5_0         1.9 MB
#     kiwisolver-1.4.2           |   py37h295c915_0          83 KB
#     matplotlib-base-3.4.3      |   py37h1058ff1_2         7.3 MB  conda-forge
#     pycocotools-2.0.4          |   py37hb1e94ed_0         112 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         9.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   cycler             conda-forge/noarch::cycler-0.11.0-pyhd8ed1ab_0 None
#   cython             pkgs/main/linux-64::cython-0.29.32-py37h6a678d5_0 None
#   kiwisolver         pkgs/main/linux-64::kiwisolver-1.4.2-py37h295c915_0 None
#   matplotlib-base    conda-forge/linux-64::matplotlib-base-3.4.3-py37h1058ff1_2 None
#   pycocotools        conda-forge/linux-64::pycocotools-2.0.4-py37hb1e94ed_0 None
#   python_abi         conda-forge/linux-64::python_abi-3.7-2_cp37m None
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2022.07.19~ --> conda-forge::ca-certificates-2022.9.24-ha878542_0 None
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            pkgs/main/linux-64::certifi-2022.9.24~ --> conda-forge/noarch::certifi-2022.9.24-pyhd8ed1ab_0 None
#
#
#
# Downloading and Extracting Packages
# matplotlib-base-3.4. | 7.3 MB    | ##################################### | 100%
# cython-0.29.32       | 1.9 MB    | ##################################### | 100%
# pycocotools-2.0.4    | 112 KB    | ##################################### | 100%
# kiwisolver-1.4.2     | 83 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Retrieving notices: ...working... done
# Looking in links: https://dl.fbaipublicfiles.com/detectron2/wheels/cu101/torch1.7/index.html
# Requirement already satisfied: detectron2==0.5 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (0.5+cu101)
# Requirement already satisfied: black==21.4b2 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from detectron2==0.5) (21.4b2)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from detectron2==0.5) (0.1.5.post20220512)
# Requirement already satisfied: tabulate in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from detectron2==0.5) (0.9.0)
# Requirement already satisfied: yacs>=0.1.6 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from detectron2==0.5) (0.1.8)
# Requirement already satisfied: pycocotools>=2.0.2 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from detectron2==0.5) (2.0.5)
# Requirement already satisfied: omegaconf>=2.1 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from detectron2==0.5) (2.2.3)
# Requirement already satisfied: hydra-core>=1.1 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from detectron2==0.5) (1.2.0)
# Requirement already satisfied: tensorboard in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from detectron2==0.5) (2.10.1)
# Requirement already satisfied: future in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from detectron2==0.5) (0.18.2)
# Requirement already satisfied: tqdm>4.29.0 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from detectron2==0.5) (4.64.1)
# Requirement already satisfied: cloudpickle in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from detectron2==0.5) (2.2.0)
# Requirement already satisfied: termcolor>=1.1 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from detectron2==0.5) (2.0.1)
# Requirement already satisfied: matplotlib in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from detectron2==0.5) (3.5.3)
# Requirement already satisfied: Pillow>=7.1 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from detectron2==0.5) (9.2.0)
# Requirement already satisfied: iopath<0.1.9,>=0.1.7 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from detectron2==0.5) (0.1.8)
# Requirement already satisfied: pydot in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from detectron2==0.5) (1.4.2)
# Requirement already satisfied: appdirs in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from black==21.4b2->detectron2==0.5) (1.4.4)
# Requirement already satisfied: click>=7.1.2 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from black==21.4b2->detectron2==0.5) (8.1.3)
# Requirement already satisfied: typing-extensions>=3.7.4 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from black==21.4b2->detectron2==0.5) (4.3.0)
# Requirement already satisfied: pathspec<1,>=0.8.1 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from black==21.4b2->detectron2==0.5) (0.10.1)
# Requirement already satisfied: toml>=0.10.1 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from black==21.4b2->detectron2==0.5) (0.10.2)
# Requirement already satisfied: regex>=2020.1.8 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from black==21.4b2->detectron2==0.5) (2022.9.13)
# Requirement already satisfied: typed-ast>=1.4.2 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from black==21.4b2->detectron2==0.5) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from black==21.4b2->detectron2==0.5) (0.4.3)
# Requirement already satisfied: pyyaml>=5.1 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.5) (6.0)
# Requirement already satisfied: numpy in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.5) (1.21.5)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from hydra-core>=1.1->detectron2==0.5) (4.9.3)
# Requirement already satisfied: packaging in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from hydra-core>=1.1->detectron2==0.5) (21.3)
# Requirement already satisfied: importlib-resources in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from hydra-core>=1.1->detectron2==0.5) (5.10.0)
# Requirement already satisfied: portalocker in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from iopath<0.1.9,>=0.1.7->detectron2==0.5) (2.6.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from matplotlib->detectron2==0.5) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from matplotlib->detectron2==0.5) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from matplotlib->detectron2==0.5) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from matplotlib->detectron2==0.5) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from matplotlib->detectron2==0.5) (1.4.4)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from tensorboard->detectron2==0.5) (3.19.6)
# Requirement already satisfied: wheel>=0.26 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from tensorboard->detectron2==0.5) (0.37.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from tensorboard->detectron2==0.5) (2.2.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from tensorboard->detectron2==0.5) (2.13.0)
# Requirement already satisfied: grpcio>=1.24.3 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from tensorboard->detectron2==0.5) (1.50.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from tensorboard->detectron2==0.5) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from tensorboard->detectron2==0.5) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from tensorboard->detectron2==0.5) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from tensorboard->detectron2==0.5) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from tensorboard->detectron2==0.5) (2.28.1)
# Requirement already satisfied: absl-py>=0.4 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from tensorboard->detectron2==0.5) (1.3.0)
# Requirement already satisfied: setuptools>=41.0.0 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from tensorboard->detectron2==0.5) (63.4.1)
# Requirement already satisfied: importlib-metadata in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from click>=7.1.2->black==21.4b2->detectron2==0.5) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.5) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.5) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.5) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.5) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->detectron2==0.5) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.5) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.5) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.5) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.5) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.5) (2.1.1)
# Requirement already satisfied: zipp>=3.1.0 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from importlib-resources->hydra-core>=1.1->detectron2==0.5) (3.10.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.5) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/kastan/utils/miniconda3/envs/openpsg/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->detectron2==0.5) (3.2.2)
